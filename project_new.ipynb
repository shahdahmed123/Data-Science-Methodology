# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#read the data
df=pd.read_csv(r"C:\Users\acacia\Desktop\data project\walmart-sales-dataset-of-45stores.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
print(df.shape)
print(df.columns)
print(df.info())
print(df.dtypes)
# Out:
# (6435, 8)
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB
# None
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# ...

# %%
print(df.describe())
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB
# None

# %%
df.sample()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1570     11  12-10-2012    1311965.09             0        69.94       3.601
#
#              CPI  Unemployment
# 1570  226.923979         6.034

# %%
cols = df.columns
df[cols].isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
new_df = df.dropna()
new_df[cols].isnull().sum()
#df.dropna(inplace = True)
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
#replace for all col 
df.fillna(0,inplace=True)

# %%
print(df['Date'])
# Out:
# 0       05-02-2010
# 1       12-02-2010
# 2       19-02-2010
# 3       26-02-2010
# 4       05-03-2010
#            ...
# 6430    28-09-2012
# 6431    05-10-2012
# 6432    12-10-2012
# 6433    19-10-2012
# 6434    26-10-2012
# Name: Date, Length: 6435, dtype: object

# %%
#fix the date 
df['Date']=pd.to_datetime(df['Date'])
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
#The weeks including these holidays are weighted five times higher in the evaluation than non-holiday weeks
x = df.	Holiday_Flag==1
df[x]
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 31        1 2010-10-09    1507460.69             1        78.69       2.565
# 42        1 2010-11-26    1955624.11             1        64.52       2.735
# 47        1 2010-12-31    1367320.01             1        48.43       2.943
# 53        1 2011-11-02    1649614.93             1        36.39       3.022
# ...     ...        ...           ...           ...          ...         ...
# 6375     45 2011-09-09     746129.56             1        71.48       3.738
# 6386     45 2011-11-25    1170672.94             1        48.71       3.492
# 6391     45 2011-12-30     869403.63             1        37.79       3.389
# 6397     45 2012-10-02     803657.12             1        37.00       3.640
# 6427     45 2012-07-09     766512.66             1        75.70       3.911
#
#              CPI  Unemployment
# ...

# %%
print(df.duplicated().to_string())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6430    False
# 6431    False
# 6432    False
# 6433    False
# 6434    False
# Length: 6435, dtype: bool

# %%
df.dropna(subset=['Date'],inplace=True)
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.	Holiday_Flag==1
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 6430    False
# 6431    False
# 6432    False
# 6433    False
# 6434    False
# Name: Holiday_Flag, Length: 6435, dtype: bool

# %%
#read the data
df=pd.read_csv(r"C:\Users\acacia\Desktop\data project\walmart-sales-dataset-of-45stores.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
#visualization
#Weekly_Sales







# Histogram for Weekly_Sales
plt.figure(figsize = (10, 7))
x = df["Weekly_Sales"]
plt.hist(x, bins = 20, color = "green")
plt.title("Weekly_Sales")
plt.xlabel("Weekly_Sales")
plt.ylabel("count")
plt.show()

# %%
# Histogram for Temperature
plt.figure(figsize = (10, 7))
x = df["Temperature"]
plt.hist(x, bins = 20, color = "pink")
plt.title("Temperature")
plt.xlabel("Temperature")
plt.ylabel("count")
plt.show()

# %%
# Histogram for Fuel_Price
plt.figure(figsize = (10, 7))
x = df["Fuel_Price"]
plt.hist(x, bins = 20, color = "red")
plt.title("Fuel_Price")
plt.xlabel("Fuel_Price")
plt.ylabel("count")
plt.show()

# %%
# Histogram for CPI
plt.figure(figsize = (10, 7))
x = df["CPI"]
plt.hist(x, bins = 20, color = "yellow")
plt.title("CPI")
plt.xlabel("CPI")
plt.ylabel("count")
plt.show()

# %%
# Histogram for Unemployment
plt.figure(figsize = (10, 7))
x = df["Unemployment"]
plt.hist(x, bins = 20, color = "purple")
plt.title("Unemployment")
plt.xlabel("Unemployment")
plt.ylabel("count")
plt.show()

# %%
#read the data
df=pd.read_csv(r"C:\Users\acacia\Desktop\data project\walmart-sales-dataset-of-45stores.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
maximum=df.groupby('Store')[['Weekly_Sales']].max()
maximum
# Out:
#        Weekly_Sales
# Store
# 1        2387950.20
# 2        3436007.68
# 3         605990.41
# 4        3676388.98
# 5         507900.07
# 6        2727575.18
# 7        1059715.27
# 8        1511641.09
# 9         905324.68
# 10       3749057.69
# 11       2306265.36
# 12       1768249.89
# 13       3595903.20
# 14       3818686.45
# 15       1368318.17
# 16       1004730.69
# 17       1309226.79
# 18       2027507.15
# 19       2678206.42
# 20       3766687.43
# 21       1587257.78
# 22       1962445.04
# 23       2734277.10
# 24       2386015.75
# 25       1295391.19
# 26       1573982.47
# 27       3078162.08
# 28       2026026.39
# 29       1130926.79
# 30        519354.88
# 31       2068942.97
# 32       1959526.96
# 33        331173.51
# 34       1620748.25
# 35       1781866.98
# 36        489372.02
# 37        605791.46
# 38        499267.66
# 39       2554482.84
# 40       1648829.18
# 41       2263722.68
# 42        674919.45
# 43        725043.04
# 44        376233.89
# ...

# %%
# Out:
#        Weekly_Sales
# Store
# 1      2.224028e+08
# 2      2.753824e+08
# 3      5.758674e+07
# 4      2.995440e+08
# 5      4.547569e+07
# 6      2.237561e+08
# 7      8.159828e+07
# 8      1.299512e+08
# 9      7.778922e+07
# 10     2.716177e+08
# 11     1.939628e+08
# 12     1.442872e+08
# 13     2.865177e+08
# 14     2.889999e+08
# 15     8.913368e+07
# 16     7.425243e+07
# 17     1.277821e+08
# 18     1.551147e+08
# 19     2.066349e+08
# 20     3.013978e+08
# 21     1.081179e+08
# 22     1.470756e+08
# 23     1.987506e+08
# 24     1.940160e+08
# 25     1.010612e+08
# 26     1.434164e+08
# 27     2.538559e+08
# 28     1.892637e+08
# 29     7.714155e+07
# 30     6.271689e+07
# 31     1.996139e+08
# 32     1.668192e+08
# 33     3.716022e+07
# 34     1.382498e+08
# 35     1.315207e+08
# 36     5.341221e+07
# 37     7.420274e+07
# 38     5.515963e+07
# 39     2.074455e+08
# 40     1.378703e+08
# 41     1.813419e+08
# 42     7.956575e+07
# 43     9.056544e+07
# 44     4.329309e+07
# ...

# %%
labels=df['Store']
data=maximum['Weekly_Sales']
plt.pie(data,labels=maximum,autopct='%0.0f')

# %%
#store_num_14
#a) Which store has maximum sales?
maximum.max()
# Out:
# Weekly_Sales    3818686.45
# dtype: float64

# %%
plt.figure(figsize = (20, 7))
df=df.groupby('Store')['Weekly_Sales'].max().to_frame().reset_index()
#Creating the bar plot
sns.barplot(x = 'Store',y = 'Weekly_Sales',data = df,palette = "Greens"  )
#Adding the aesthetics

plt.title('Bar Chart Stors vs. Max_sales')
plt.xlabel('Store_number')
plt.ylabel('max_sales')
#Show the Bar Chart Plot
plt.show()

# %%
df['Store'].sum()
# Out:
# 1035

# %%
df['Weekly_Sales'].sum()
# Out:
# 81787955.19000001

# %%
df['Weekly_Sales'].max()
# Out:
# 3818686.45

# %%
df.groupby('Store').count()
# Out:
#        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  CPI  \
# Store
# 1       143           143           143          143         143  143
# 2       143           143           143          143         143  143
# 3       143           143           143          143         143  143
# 4       143           143           143          143         143  143
# 5       143           143           143          143         143  143
# 6       143           143           143          143         143  143
# 7       143           143           143          143         143  143
# 8       143           143           143          143         143  143
# 9       143           143           143          143         143  143
# 10      143           143           143          143         143  143
# 11      143           143           143          143         143  143
# 12      143           143           143          143         143  143
# ...

# %%
def data_range(series):
    return series.max() - series.min()

df.groupby('Store')[['Weekly_Sales', 'CPI']].agg(data_range)
# Out:
#        Weekly_Sales        CPI
# Store
# 1        1071050.89  13.106825
# 2        1785613.24  13.079878
# 3         266393.03  13.367750
# 4        1913849.68   5.129097
# 5         247263.36  13.150537
# 6        1466322.00  13.226449
# 7         687041.66   9.837834
# 8         739101.97  13.371400
# 9         452419.46  13.385825
# 10       2121350.38   5.129097
# 11       1205846.67  13.367750
# 12        966144.39   5.129097
# 13       1962240.08   5.129097
# 14       2339171.79  10.684039
# 15        914134.75   7.383797
# 16        636130.69   9.837834
# 17        673364.24   5.129097
# 18       1486584.21   7.383797
# 19       1497001.89   7.383797
# 20       2005670.92  12.541412
# 21        991039.54  13.079878
# 22       1188182.76   7.585156
# 23       1717521.00   7.383797
# 24       1328725.34   7.383797
# 25        736596.56  12.541412
# 26        764149.26   7.383797
# 27       1814627.22   7.585156
# 28        946357.28   5.129097
# 29        734939.55   7.383797
# ...

# %%
df['Temperature'].mean()
# Out:
# 60.66378243978234

# %%
#e) Plot the relations between weekly sales vs. other numeric features and give insights.




plt.figure(figsize = (50, 7))
df=df.groupby('Weekly_Sales')['Temperature'].mean().to_frame().reset_index()
#Creating the bar plot
sns.barplot(y = 'Temperature',x = 'Weekly_Sales',data = df,palette = "Blues")
#Adding the aesthetics Column chart
plt.title('Bar Chart Temperature vs. Weekly sales')
plt.xlabel('mean Temperature')
plt.ylabel('weekly sales')
#Show the Bar Chart Plot
plt.show()
